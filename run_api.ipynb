# %%
from s3_functions import *

# %%
a = save_model_to_s3(10, 1020)

# %%
# !docker run -d \
  -p 9000:9000 \
  -p 9001:9001 \
  -e MINIO_ROOT_USER=minioadmin \
  -e MINIO_ROOT_PASSWORD=minioadmin \
  -v ./minio_data:/data \
  minio/minio:latest \
  minio server /data --console-address ":9001"
# Out:
# 0d65926e51f208666f56eb86d67369d166ce2f359e51d6c5f53b9676b7f5a819

# %%
# !fastapi dev ml_api.py
# Out:
# ]11;?\]10;?\
#    FastAPI   Starting development server 🚀
#
#              Searching for package file structure from directories with
#              __init__.py files
#              Importing from /Users/nikitaaksenov/Desktop/Masters/MLOPS/github
#
#     module   🐍 ml_api.py
#
#       code   Importing the FastAPI app object from the module with the following
#              code:
#
#              from ml_api import app
#
#        app   Using import string: ml_api:app
#
#     server   Server started at ]8;id=555226;http://127.0.0.1:8000\http://127.0.0.1:8000]8;;\
#     server   Documentation at ]8;id=848851;http://127.0.0.1:8000/docs\http://127.0.0.1:8000/docs]8;;\
#
#        tip   Running in development mode, for production use: fastapi run
#
#              Logs:
#
# ]11;?\]10;?\]11;?\]10;?\      INFO   Will watch for changes in these directories:
#              ['/Users/nikitaaksenov/Desktop/Masters/MLOPS/github']
# ...
